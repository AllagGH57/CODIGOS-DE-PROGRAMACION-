# %% [markdown]
# <a href="https://colab.research.google.com/github/AllagGH57/CODIGOS-DE-PROGRAMACION-/blob/main/P8_Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numerodeN=int(input("Cuantos numeros me quieres dar?: "))
numeromayor=int (input("dame el primer numero: "))
for i in range(numerodeN):
    numero=int(input("dame el numer que quieres:"))
    if numero > numeromayor:
     numeromayor=numero
print("ESTE ES TU NUMER MAYOR",numeromayor)
# Out:
# Cuantos numeros me quieres dar?: 5
# dame el primer numero: 19
# dame el numer que quieres:35
# dame el numer que quieres:2
# dame el numer que quieres:15
# dame el numer que quieres:5
# dame el numer que quieres:10
# ESTE ES TU NUMER MAYOR 35
